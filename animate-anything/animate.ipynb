# %%
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh -O miniconda.sh
# !chmod +x miniconda.sh
# !bash ./miniconda.sh -b -f -p /usr/local
# Out:
# --2024-04-22 05:14:23--  https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.32.241, 104.16.191.158, 2606:4700::6810:20f1, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.32.241|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 143351488 (137M) [application/octet-stream]
# Saving to: ‘miniconda.sh’
#
# miniconda.sh        100%[===================>] 136.71M   162MB/s    in 0.8s
#
# 2024-04-22 05:14:24 (162 MB/s) - ‘miniconda.sh’ saved [143351488/143351488]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
# Preparing transaction: ...working... done
# Executing transaction: ...working... done
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
# ...

# %%
# !git clone https://github.com/relmelegy/Sketch-to-Video.git
# Out:
# Cloning into 'Sketch-to-Video'...
# remote: Enumerating objects: 20, done.
# remote: Counting objects: 100% (20/20), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 20 (delta 5), reused 10 (delta 2), pack-reused 0
# Receiving objects: 100% (20/20), 4.57 KiB | 1.14 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# %cd Sketch-to-Video/
# Out:
# /content/Sketch-to-Video

# %%
# !git clone https://github.com/alibaba/animate-anything.git
# Out:
# Cloning into 'animate-anything'...
# remote: Enumerating objects: 254, done.
# remote: Counting objects: 100% (60/60), done.
# remote: Compressing objects: 100% (35/35), done.
# remote: Total 254 (delta 34), reused 34 (delta 25), pack-reused 194
# Receiving objects: 100% (254/254), 29.28 MiB | 25.96 MiB/s, done.
# Resolving deltas: 100% (134/134), done.

# %%
# %cd animate-anything/
# Out:
# /content/Sketch-to-Video/animate-anything

# %%
# !conda create -y -n animation python=3.10

# %%
# %%shell
# eval "$(conda shell.bash hook)" # This initializes Conda for shell interaction
# conda activate animation

# %%
# !pip install -r requirements.txt

# %%
# %%shell
# pip install accelerate==0.21.0
# pip install torch==2.0.0
# pip install torchvision
# pip install diffusers==0.24.0
# pip install transformers==4.36.2
# pip install einops
# pip install decord
# pip install tqdm
# pip install safetensors
# pip install omegaconf
# pip install opencv-python
# pip install pydantic
# pip install compel
# pip install easydict
# pip install rotary_embedding_torch
# pip install imageio[ffmpeg]
# pip install gradio
# pip install httpx[socks]

# %%
# %cd animate-anything
# !mkdir -p output/latent
# %cd output/latent
# Out:
# /content/drive/MyDrive/Spring24/Applied-CV/Project/animate/Sketch-to-Video/animate-anything

# %%
# !wget https://cloudbook-public-production.oss-cn-shanghai.aliyuncs.com/animation/animate_anything_512_v1.02.tar
# Out:
# --2024-04-22 05:38:55--  https://cloudbook-public-production.oss-cn-shanghai.aliyuncs.com/animation/animate_anything_512_v1.02.tar
# Resolving cloudbook-public-production.oss-cn-shanghai.aliyuncs.com (cloudbook-public-production.oss-cn-shanghai.aliyuncs.com)... 106.14.228.121
# Connecting to cloudbook-public-production.oss-cn-shanghai.aliyuncs.com (cloudbook-public-production.oss-cn-shanghai.aliyuncs.com)|106.14.228.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7351644160 (6.8G) [application/x-tar]
# Saving to: ‘animate_anything_512_v1.02.tar’
#
# animate_anything_51 100%[===================>]   6.85G  17.6MB/s    in 8m 30s
#
# 2024-04-22 05:47:28 (13.8 MB/s) - ‘animate_anything_512_v1.02.tar’ saved [7351644160/7351644160]

# %%
# !tar -xvf /content/Sketch-to-Video/animate-anything/output/latent/animate_anything_512_v1.02.tar

# %%
# %%shell
# cd ..
# cd ..

# %%
# !python train.py --config output/latent/animate_anything_512_v1.02/config.yaml --eval validation_data.prompt_image=example/img.png validation_data.prompt='A cat sliding on the sofa.'
# Out:
# /usr/local/lib/python3.12/site-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/site-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/site-packages/diffusers/utils/outputs.py:63: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   torch.utils._pytree._register_pytree_node(
# motion mask True, motion_strength True
# 33 Attention layers using Scaled Dot Product Attention.
# Loading pipeline components...: 100% 5/5 [00:00<00:00, 57.07it/s]
# ...
